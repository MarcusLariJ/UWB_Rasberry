# %%
import robot_plotter as rp
import sim_helper_funcs as hfunc
import robot_sim as sim

# Simple file to draw all the generated trajectories:
dt = 0.01
xanc1, xanc2 = hfunc.anc_setup4()
pos1, y_IMU1, _ = hfunc.path1_slow(dt=dt)
pos2, y_IMU2, _ = hfunc.path2_slow(dt=dt)
pos3, y_IMU3, _ = hfunc.path3_slow(dt=dt)
pos4, y_IMU4, _ = hfunc.path4_slow(dt=dt)
pos5, y_IMU5, _ = hfunc.path5_slow(dt=dt)
pos6, y_IMU6, _ = hfunc.path6_slow(dt=dt)

# Preview plot:
fig, axtest = rp.setup_plot()
rp.plot_position(axtest, pos1[:,::100], color='black', linestyle=':', marker='v')
rp.plot_position(axtest, pos2[:,::100], color='black', linestyle=':', marker='o')
rp.plot_position(axtest, pos3[:,::100], color='black', linestyle=':', marker='^')
#rp.plot_position(axtest, pos4[:,::100], color='black', linestyle=':', marker='<')
#rp.plot_position(axtest, pos5[:,::100], color='black', linestyle=':', marker='>')
#rp.plot_position(axtest, pos6[:,::100], color='black', linestyle=':', marker='1')

anchor1 = sim.Anchor(x0=xanc1)
anchor2 = sim.Anchor(x0=xanc2)

anchor1.draw_position(axtest, color='orange')
anchor2.draw_position(axtest, color='green')
